# %% [markdown]
# ## popularity processing

# %%
# move file to backend folder first
import csv
from cocktailLab import CocktailLab
import editdistance
import numpy as np
import math

# %%
cocktailLab = CocktailLab()

# %%
def popfile_to_names(file):
    """ Returns a dictionary of format {'cocktail name' : 'ingred1,ingred2'}
    Parameters:
    file: name of file

    ***Note: CURRENTLY CONFIGURED FOR cocktail_flavors_ingreds_combined***
    """
    with open(file, encoding="utf8") as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        out = {}
        for row in csv_reader:
            if line_count == 0:
                line_count += 1
            else:
                out[row[2].lower()] = ""
    return out

# %%
popdrinks = popfile_to_names("./data/popularity.csv")

# %%
ourdrinks = list(cocktailLab.cocktail_name_to_index.keys())

# %%
for popdrink in popdrinks:
    for drink in ourdrinks:
        if popdrink in drink or drink in popdrink:
            popdrinks[popdrink] = drink

# %%
[(i, popdrinks[i]) for i in popdrinks]
# Out:
# [("'57 chevy", "'57 chevy with a white license plate"),
#  ('caipirinha', 'dark caipirinha'),
#  ('long island icetea', ''),
#  ('piña colada', ''),
#  ('tall blonde', ''),
#  ('wiki waki woo', ''),
#  ('ghostbuster', ''),
#  ('mai tai', 'kentucky mai tai'),
#  ('77 sunset strip', ''),
#  ('zombie', ''),
#  ('bleeding heart', ''),
#  ('time bomb', ''),
#  ('sunny', ''),
#  ('daiquiri slush', ''),
#  ('cuba libre', ''),
#  ('union jack', ''),
#  ('lemon drop', 'lemon drop'),
#  ('american beauty (aperitif)', ''),
#  ('sex on the beach', ''),
#  ('baby aspirin', ''),
#  ('boston tea party', ''),
#  ('mojito', 'pink mojito'),
#  ('mojito original', 'mojito'),
#  ('highfly', ''),
#  ("veronika's birthday", ''),
#  ('b52', ''),
#  ('cuban special', ''),
#  ('sputnik', ''),
#  ('baby face', 'ace'),
#  ('grasshopper', ''),
#  ('gimlet', ''),
#  ("planter'spunch (1)", ''),
#  ('a day at the beach', ''),
#  ('lumumba', ''),
#  ('white russian (der echte!)', ''),
#  ('absinth', ''),
#  ('sex on the beach 3', ''),
#  ('tequila sunrise', 'tequila sunrise'),
#  ('---', ''),
#  ('---nazi_from_hell', ''),
#  ('erdbeerbowle', ''),
#  ('kaukasier', ''),
#  ('seven and seven', ''),
#  ('dream cocktail', ''),
#  ('strawberry pineapple milk shake', ''),
#  ('grand slam trend', ''),
#  ('irish flag (alkoholisch)', ''),
#  ('kamikaze shot', ''),
#  ('bull shot', ''),
#  ('wild russian', ''),
#  ('caipiroska fragola', ''),
#  ('asti pink', ''),
#  ('bitter sweet (aperitif)', ''),
#  ('bamboo (aperitif)', ''),
#  ('911 targa', ''),
#  ('1103', ''),
#  ('after eight', ''),
#  ('aperol sour', ''),
#  ('zerstörer', ''),
#  ('omas offenes bein', ''),
#  ('james bond martini', 'martini'),
#  ('moscow mule 2', ''),
#  ('london fog', ''),
#  ('fire bomb', ''),
#  ('boston cooler', ''),
#  ('whiskey sour', ''),
#  ('a b v', ''),
#  ('alexander', 'flambeed brandy alexander'),
#  ('pina colada "real"', ''),
#  ('snowball fizz', ''),
#  ('evilsch', ''),
#  ('hot whiskey toddy', ''),
#  ('feuerzangenbowle', ''),
#  ('b and b', ''),
#  ('gin-n-fruit', ''),
#  ('gine and tonic', ''),
#  ('talos green', ''),
#  ('di amore dream', ''),
#  ('birnenaperitif', ''),
#  ('kir framboise', 'kir'),
#  ('gin alexander', ''),
#  ('queen of scots', ''),
#  ('apricot sour', ''),
#  ('traffic light cooler', ''),
#  ('manhattan medium 2', 'manhattan'),
#  ('russian bear cocktail', ''),
#  ('jäger ace', 'ace'),
#  ('blueberry martini', 'martini'),
#  ('twin hills', ''),
#  ('speed king', ''),
#  ('schwanzlstürzer', ''),
#  ('bavorak', ''),
#  ('martini dry', 'martini'),
#  ('whiskey sour 2', ''),
#  ('alexander 2', ''),
#  ('lady finger', ''),
#  ('merlin', ''),
#  ('pangalaktischer donnergurgler', ''),
#  ('froschmilch', ''),
#  ('frensh 75 (cdrink)', '')]

# %%
# 
popdrinks['pina colada "real"'] = 'pink colada'
popdrinks['piña colada'] = 'pink colada'
popdrinks['frensh 75 (cdrink)'] = 'french 75'

# %%
for popdrink in popdrinks:
    if popdrinks[popdrink] != "":
        continue
    distances = []
    for drink in ourdrinks:
        distances += [editdistance.eval(popdrink, drink)]
    a = np.array(distances)
    print((popdrink, ourdrinks[np.argmin(a)]))
# Out:
# ('long island icetea', 'holland house')
# ('tall blonde', 'la la land')
# ('wiki waki woo', 'andy warhol')
# ('ghostbuster', 'stinger')
# ('77 sunset strip', 'le sang et sable')
# ('zombie', '3am')
# ('bleeding heart', 'blood & sand')
# ('time bomb', 'bird on')
# ('sunny', 'monet')
# ('daiquiri slush', 'apricot blush')
# ('cuba libre', 'culebra')
# ('union jack', 'applejack')
# ('american beauty (aperitif)', 'round pond aperitif')
# ('sex on the beach', 'redondo beach')
# ('baby aspirin', 'dark caipirinha')
# ('boston tea party', 'bird on a wire')
# ('highfly', 'bird on')
# ("veronika's birthday", 'fiona graham')
# ('b52', '3am')
# ('cuban special', 'army special')
# ('sputnik', 'martini')
# ('grasshopper', 'beachcomber')
# ('gimlet', 'monet')
# ("planter'spunch (1)", 'prata punch')
# ('a day at the beach', 'adam & eve')
# ('lumumba', 'club med')
# ('white russian (der echte!)', 'citrus quo (adapted)')
# ('absinth', 'a.nise')
# ('sex on the beach 3', 'redondo beach')
# ('---', '3am')
# ('---nazi_from_hell', 'bacio romana')
# ('erdbeerbowle', 'creole')
# ('kaukasier', 'a.nise')
# ('seven and seven', 'green and gold')
# ('dream cocktail', 'arapa cocktail')
# ('strawberry pineapple milk shake', 'stranger in the alps')
# ('grand slam trend', 'la la land')
# ('irish flag (alkoholisch)', 'irish goodbye')
# ('kamikaze shot', 'a love song')
# ('bull shot', 'bird on')
# ('wild russian', 'gold rush')
# ('caipiroska fragola', 'caipirinha')
# ('asti pink', 'astoria')
# ('bitter sweet (aperitif)', 'the pink aperitivo')
# ('bamboo (aperitif)', 'abbey martini')
# ('911 targa', '10 to 7')
# ('1103', 'a1')
# ('after eight', 'day for night')
# ('aperol sour', 'abano sour')
# ('zerstörer', 'vesper')
# ('omas offenes bein', 'kiss of persuasion')
# ('moscow mule 2', 'mexico mule')
# ('london fog', 'lemon drop')
# ('fire bomb', 'bird on')
# ('boston cooler', 'beachcomber')
# ('whiskey sour', 'pisco sour')
# ('a b v', 'a1')
# ('snowball fizz', 'soma fizz')
# ('evilsch', 'kiss')
# ('hot whiskey toddy', 'the tahoe toddy')
# ('feuerzangenbowle', 'feingold')
# ('b and b', 'bird on')
# ('gin-n-fruit', 'chingerito')
# ('gine and tonic', 'iron tonic')
# ('talos green', '3 & tree')
# ('di amore dream', 'fiona graham')
# ('birnenaperitif', 'bianco americano')
# ('gin alexander', 'final ward')
# ('queen of scots', 'abano sour')
# ('apricot sour', 'apricot blush')
# ('traffic light cooler', 'flight to peru')
# ('russian bear cocktail', 'bushido cocktail')
# ('twin hills', 'hippi hill')
# ('speed king', 'the mad king')
# ('schwanzlstürzer', 'spice and stormy')
# ('bavorak', 'mandrake')
# ('whiskey sour 2', 'pisco sour')
# ('alexander 2', 'buccaneer')
# ('lady finger', 'sidewinder')
# ('merlin', 'martini')
# ('pangalaktischer donnergurgler', 'gran classico negroni')
# ('froschmilch', 'french 33')

# %%
pop_rawscores = {}

# %%
def popfile_pops(file):
    """ Returns a dictionary of format {'cocktail name' : 'ingred1,ingred2'}
    Parameters:
    file: name of file

    ***Note: CURRENTLY CONFIGURED FOR cocktail_flavors_ingreds_combined***
    """
    with open(file, encoding="utf8") as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            if line_count == 0:
                line_count += 1
            else:
                if popdrinks[row[2].lower()] != "":
                    name = row[2].lower()
                    if name not in pop_rawscores:
                      pop_rawscores[row[2].lower()] = [int(row[1])]
                    else:
                        pop_rawscores[name] += [int(row[1])]

# %%
popfile_pops("./data/popularity.csv")

# %%
pop_sumscores = {}
for drink in pop_rawscores:
    pop_sumscores[drink] = math.log(11 * len(pop_rawscores[drink]) - sum(pop_rawscores[drink]) + 1)

# %%
popdrinks_short = dict((k, v) for k, v in popdrinks.items() if v)

# %%
from cocktailLab import CocktailLab
cl = CocktailLab()

# %%
popdrinks_short_inv = {v: k for k, v in popdrinks_short.items()}
short_name_to_index = {
    name: index for index, name in enumerate(popdrinks_short_inv)
}
short_index_to_name = {v:k for k, v in short_name_to_index.items()}

# %%
# want: to label each of our drinks with a popularity score, based on how close they are to a drink in the popular dataset * popularity factor
# make doc-vocab matrix out of popular drinks (popdrinks_short_inv)
# get the cos sim measure b/t each of our drinks and the closest popular drink using that doc-vocab matrix
# to get the popularity score, use the pop_sumscores dictionary

# %%
pop_ingreds = [cl.cocktail_names_to_ingreds[c] for c in popdrinks_short_inv]

# %%
pop_idxs = [cl.cocktail_name_to_index[i] for i in popdrinks_short_inv]
pop_idxs
# Out:
# [0, 154, 410, 271, 296, 411, 342, 29, 495, 321, 194, 277, 315, 205]

# %%
cl.ingreds_doc_by_vocab[pop_idxs].shape
# Out:
# (14, 949)

# %%
# process every drink that doesn't have a score
assigned_pop_scores = []
scores = []
cos_scores = []
for drink in ourdrinks:
    # skip drinks that alr have a score
    if drink in popdrinks_short_inv:
        # continue
        pass
    # print(drink, end="")
    ranks = (cl.cos_rank(
        cl.ingreds_doc_by_vocab[cl.cocktail_name_to_index[drink]],
        cl.ingreds_doc_by_vocab[pop_idxs]
    ))
    actual_idx = pop_idxs[ranks[0][0]]
    # print(list(popdrinks_short_inv.keys())[ranks[0][0]])
    assigned_pop_scores += [{
        "drink name" : drink,
        "closest popular drink" : cl.cocktail_index_to_name[actual_idx],
        "score" : ranks[0][1] * pop_sumscores[popdrinks_short_inv[cl.cocktail_index_to_name[actual_idx]]]
    }]
    scores += [ranks[0][1] * pop_sumscores[popdrinks_short_inv[cl.cocktail_index_to_name[actual_idx]]]]
    cos_scores += [ranks[0][1]]

# %%
field_names = ["drink name", "closest popular drink", "score"]
with open("all_popular_scores.csv", "w") as file:
    writer = csv.DictWriter(file, fieldnames=field_names)
    writer.writeheader()
    writer.writerows(assigned_pop_scores)

# %%
cl.ingreds
# Out:
# {"'57 chevy with a white license plate": 'creme de cacao,vodka',
#  '10 to 7': '1 oz no. 209 gin, 1 oz luxardo maraschino liqueur, 1 oz st. germain, 1 oz lemon juice',
#  '155 belmont': 'dark rum,light rum,vodka,orange juice',
#  "1880's americana": '2 oz hirsch small batch reserve bourbon, 10 ml amer picon, 10 ml house cola syrup',
#  '20th century': "1.5 oz no.3 london dry gin, .75 oz tempus fugit kina l'aero d'or, .75 oz tempus fugit creme de cacao, .75 oz fresh lemon juice",
#  '3 & tree': '1.5 oz no.3 london dry gin,  top fever-tree tonic water, .25 oz maurin quina',
#  '3 degrees': '1.75 oz no.3 london dry gin, .75 oz velvet falernum, .5 oz lime juice, .5 oz pear sage foam, 1 float prosecco',
#  '3am': "1.5 oz no.3 london dry gin, .75 oz h by hine, .75 oz luxardo triplum (triple sec), .5 oz king's ginger liqueur, .5 oz fresh lime juice",
#  '50/50 split': '1.5 oz junipero gin, .75 oz dry vermouth, .75 oz tempus fugit alessio vermouth bianco, 1 dash the bitter truth orange bitters',
#  '7th heaven': '1.5 oz no.3 london dry gin, .5 oz luxardo maraschino liqueur, 1 oz grapefruit juice, .25 oz pages elderflower syrup, 1 dash angostura bitters',
#  '9 1/2 weeks': 'absolut citron,orange curacao,strawberry liqueur,orange juice',
#  'a gift from zara': '1.5 oz luxardo bitter bianco, .75 oz london dry gin, .75 oz elderflower liqueur, 2 dash citric acid, 4 drops orange flower water, 2.5 oz topo chico mineral water',
#  "a gilligan's island": 'vodka,peach schnapps,orange juice,cranberry juice',
#  'a love song': "1 oz no.3 london dry gin, 1 oz maurin quina, .5 oz luxardo bitter, .5 oz king's ginger liqueur",
#  'a mi manera (my way) pisco punch': '2 oz barsol selecto italia pisco, 1 oz luxardo apricot liqueur, 2 oz minta soda, 1 pinch citric acid or lime juice, 1 scoop pineapple sorbet',
#  'a regal air ': "3 oz domingo perez marin 'la guita' manzanilla sherry, .5 oz king's ginger liqueur, .25 oz chartreuse , .25 oz juice of an orange",
#  'a tall tell': "9 oz c. drouin calvados selection, 6 oz marrakesh mint tea, 6 oz prosecco, 3 oz king's ginger liqueur, 2 oz lemon juice, 1.5 oz velvet falernum, .5 oz dale degroff's pimento aromatic bitters",
#  'a true amaretto sour': 'amaretto,lemon,ice,maraschino cherry',
#  'a.d.m. (after dinner mint)': 'white creme de menthe,southern comfort,vodka,hot chocolate',
#  'a.nise': '1.5 oz pink pigeon rum, .5 oz luxardo amaretto di saschira, .5 oz osha falernum, .5 oz lemon juice, 1 oz pineapple juice, 3 dash orange bitters',
#  'a1': 'gin,grand marnier,lemon juice,grenadine',
#  'abano sour': '1.5 oz luxardo amaro abano, 1 oz fresh lemon juice, .25 oz agave nectar, 1 dash grapefruit bitters, .5 oz egg white',
#  'abbey martini': 'gin,sweet vermouth,orange juice,angostura bitters',
#  'above my pay grade': '1.5 oz semper fi white whiskey, .75 oz chateau de montifaud pineau des charentes rose, .75 oz tempus fugit gran classico bitter, 3 dash house-made citrus bitters',
#  'abrazo latino': '1.5 oz chinaco reposado tequila, .75 oz luxardo amaro abano, .75 oz luxardo triplum (triple sec)',
#  'absolut summertime': 'absolut citron,sweet and sour,sprite,soda water,lemon',
#  'absolutely fabulous': 'vodka,cranberry juice,champagne',
#  'absolutly screwed up': 'absolut citron,orange juice,triple sec,ginger ale',
#  'ace': 'gin,grenadine,heavy cream,milk,egg white',
#  'across the pond': "1 oz junipero gin, 1 oz king's ginger liqueur, .5 oz round pond meyer lemon syrup, .75 oz fresh lemon juice, 1 splash soda water",
#  'adam & eve': 'gin,cognac,creme de cassis,fresh lemon juice',
#  'addington': 'sweet vermouth,dry vermouth,soda water',
#  'addison': 'gin,vermouth',
#  'addison special': 'vodka,grenadine,orange juice',
#  'adios amigos cocktail': 'rum,dry vermouth,cognac,gin,fresh lime juice,sugar syrup,water',
#  'alaska cocktail': '2.25 oz no.3 london dry gin, .75 oz green chartreuse, 3 dash orange bitters',
#  'almond brother': '2 oz reposado tequila, .25 oz luxardo amaretto di saschira, 1 tsp luxardo apricot liqueur, .75 oz lime juice, .25 oz luxardo orgeat syrup, .25 oz maple syrup',
#  'almond crusta': '1 oz h by hine, .5 oz junipero gin, .75 oz lemonjuice, .5 oz orgeat, 1 dash angostura bitters',
#  'amaretto bourbon punch': '37.5 oz hirsch small batch reserve bourbon, 6.25 oz luxardo amaretto di saschira, 12.5 oz fresh lemon juice, 12.5 oz sparkling apple juice, 6.25 oz simple syrup, 37.5 oz seltzer',
#  'amaretto jello shot, why not': '2 cups boiling water, 6 packages raspberry jello packages, 1.25 cup luxardo amaretto di saschira, .25 cup fresh lime juice, .5 cup cold water',
#  'amaretto rose': '1.5 oz luxardo amaretto di saschira, .5 oz lime juice,  fill club soda',
#  'amaretto sour': '2 oz luxardo amaretto di saschira, 1 oz fresh lemon juice, .75 oz simple syrup, .5 oz egg white',
#  'amaretto sour (modern)': '2 oz luxardo amaretto di saschira, 1 oz fresh squeezed lemon juice, .5 oz pasteurized egg white, 1, small scoop lemon sorbet',
#  'amaretto sour bv-style': '1.5 oz luxardo amaretto di saschira, .5 oz bourbon, .5 oz fresh\xa0lime juice, .75 oz pineapple juice, .75 oz fresh egg white, 2 dash angostura bitters',
#  'amaretto sourball': '1 oz vodka, 1 oz luxardo amaretto di saschira, 1 splash lemon juice, 1 splash orange juice',
#  'americana fizz (layered cocktail)': '1.5 oz junipero gin, .75 oz fresh lemon juice, .25 oz simple syrup, .75 oz the genuine curacao liqueur blue, .5 oz luxardo aperitivo,  splash perrier grapefruit',
#  'and the cherry on top is...': '1 oz luxardo maraschino liqueur, 3 oz vodka, .5 oz root 23 cherry almond simple syrup, 1 oz lemon juice,  splash club soda',
#  'andy warhol': '1.5 oz no.3 london dry gin, .5 oz tempus fugit alessio vermouth bianco, 1 oz fresh squeezed ruby grapefruit, .5 oz simple syrup, 3 slices cucumber, 1 fill soda water',
#  'angel face (classic)': '1 oz luxardo apricot liqueur, 1 oz c. drouin calvados selection, 1 oz no.3 london dry gin',
#  "angel's face": '1 oz no.3 london dry gin, 1 oz applejack, 1 oz luxardo apricot liqueur',
#  'aperitivo spritz': '2 oz luxardo aperitivo, 3 oz prosecco, 1 splash sparkling water',
#  'applejack': 'jack daniels,midori melon liqueur,sour mix',
#  'apples & grapes': "1.5 oz tempus fugit kina l'aero d'or, 1 oz c. drouin pommeau de normandie, 2 dash orange bitters",
#  'apricot blush': "1 oz vanilla flavored vodka, .75 oz luxardo apricot liqueur, 1 oz fresh sweet n' sour mix, 3 oz prosecco,  oz sliced plum, 2 sprigs mint sprig",
#  'apricot lady': '1.25 oz light rum, 1 oz luxardo apricot liqueur, .25 tsp triple sec, 1 tbsp lime juice, 1  egg white',
#  'arapa cocktail': '1.5 oz barsol supremo moste verde italia pisco, .5 oz junipero gin, .75 oz luxardo triplum (triple sec), .5 oz lemon juice, 1 dash fee bros. rhubard bitters',
#  'arizona stingers': 'absolut vodka,iced tea',
#  'arizona twister': 'vodka,malibu rum,gold tequila,orange juice,pineapple juice,cream of coconut,grenadine,ice,pineapple',
#  'army special': 'vodka,gin,lime juice cordial,ice',
#  'assemble mule': "20 ml monkey shoulder blended scotch whisky, 15 ml king's ginger liqueur, 20 ml mezcal, 20 ml agave syrup, 15 ml lime juice, 4  mint leaves,  top prosecco",
#  'astoria': '2 oz junipero gin, 1 oz dry vermouth, 1-2 dash orange bitters',
#  'aviation': 'gin,lemon juice,maraschino liqueur',
#  'aviation (adapted)': '2 oz no.3 london dry gin, .5 oz luxardo maraschino liqueur, .5 oz fresh lemon juice, .25 oz tempus fugit liqueur de violettes',
#  'b-string': '1.5 oz h by hine, 1 oz lustau amontillado sherry, .5 oz giffard banane du brésil, 3 dash house-made roasted banana bitters (or bittermens tiki bitters)',
#  "bachelor's bait": '2 oz junipero gin, 6 dash grapefruit shrub, 3 dash orange bitters, 1 dash grenadine, 1  egg white',
#  'bacio romana': '1.5 oz luxardo bitter bianco, .5 oz barsol pisco, .5 oz luxardo maraschino liqueur, .5 oz dry vermouth',
#  'baile de verano': '2 oz barsol perfecto amor (aperitif wine), .5 oz penny blue mauritian rum, 6 dash celery shrub, 3 dash house-made tarragon tincture',
#  'bajo control': '2 oz barsol perfecto amor (aperitif wine), 1 oz dolin dry vermouth, .75 oz lemon juice, .5 oz agave syrup',
#  'bakko & zengo': '1.5 oz nikka coffey grain whisky, .25 oz house-made allspice dram, .25 oz heavy cream, .25 oz simple syrup, 1  whole egg, 2 dash chocolate bitters',
#  "banana's froster": '1.5 oz junipero gin, 1 oz briottet creme de banane, .5 oz cream (half & half), 2 dash chocolate bitters',
#  'barbary coast bulldog': '1.5 oz hophead vodka, .75 oz luxardo espresso italian liqueur, 2 oz cream, 2 oz mexican coca cola',
#  'barrel aged ginger negroni': "1 part junipero gin, 1 part king's ginger liqueur, 1 part campari, 1 part sweet vermouth",
#  'basil gin and tonic': '1 oz lime juice, 1 spg basil, 2 oz tonic water, 1 oz junipero gin',
#  'basilway daquiri': "1.5 oz basil-infused white rum, .5 oz king's ginger liqueur, .25 oz fresh lime juice, .25 oz luxardo maraschino liqueur, 1 bsp, large grapefruit sorbet",
#  'bay city shandy': '1.5 oz hophead vodka, .75 oz giffard pamplemousse, .5 oz lemon juice, 2 dash orange bitters,  top ipa',
#  'beachcomber': '1.5 oz light rum, .75 oz  cointreau, .75 oz lime juice, .25 oz luxardo maraschino liqueur, .125 oz simple syrup (optional)',
#  'bermuda highball': "1 oz chateau de montifaud cognac vsop, 1 oz plymouth gin, 1 oz contratto bianco vermouth, 2 dash regans' orange bitters no. 6, 3 oz club soda",
#  'bianco americano': "1.5 oz luxardo bitter bianco, 1 oz tempus fugit kina l'aero d'or, .5 oz junipero gin",
#  'big and bright': "1.5 oz no.3 london dry gin, .5 oz king's ginger liqueur, 1 oz fresh grapefruit juice, .25 oz honey, .25 oz fresh lime juice , 1 dash fire and damnation bitters, 1 splash club soda",
#  'bird is the word': '.75 oz pink pigeon rum, .75 oz luxardo maraschino liqueur, .75 oz green chartreuse, .5 oz lime juice, .5 oz pineapple juice',
#  'bird on': '.75 oz tempus fugit creme de menthe glaciale, .75 oz tempus fugit alessio vermouth bianco, .75 oz h by hine, .375 oz lemon juice, .375 oz lime juice',
#  'bird on a wire': "1.5 oz pink pigeon rum, .5 oz nikka whisky taketsuru pure malt 12 yo, .5 oz peychaud's bitters, .5 oz luxardo maraschino liqueur",
#  'bird to buck': '1 1/2 part pink pigeon rum, 1/2 part benedictine, 1/4 part orgeat syrup, 1/2 part lime,  part fee brothers whiskey barrel bitters',
#  'black jam': '1.5 oz luxardo fernet, .75 oz honey syrup, .75 oz fresh lemon juice, 4 oz tonic water',
#  'blood & sand': '.75 oz glenrothes vintage reserve, .75 oz tempus fugit alessio vermouth di torino rosso, .75 oz luxardo sangue morlacco cherry liqueur, .75 oz orange juice',
#  'bloody fernet': '1 oz luxardo fernet, .75 oz luxardo maraschino liqueur, 2 scoop blood orange sorbet',
#  'blue 88': '1.5 oz no.3 london dry gin, .25 oz lemon juice, .25 oz pages elderflower syrup, .25 oz tempus fugit liqueur de violettes, .25 oz luxardo maraschino liqueur',
#  'boko buku': '1.5 oz mezcal, .75 oz don ciccio & figli concerto, .125 oz vanilla marinade, 8 dash mole bitters',
#  "boomin' granny": '1.5 oz h by hine, 1 oz granny smith apple juice, .5 oz fresh lime juice, .5 oz acacia honey syrup,  top sparkling wine',
#  'bourbon crusta': '2 oz bourbon, .25 oz orchard syrup, .25 oz lemon juice, 1 bsp luxardo triplum (triple sec), 1 bsp luxardo maraschino liqueur, 3 dash boker’s bitters',
#  'brazilian mai tai': '1.5 oz ypioca brasilizar cachaca prata classica, 3 oz mai tai mix, 1 splash soda water, 1 float english harbour rum',
#  'brazilian mule punch': '2 part ypioca brasilizar cachaca prata reserva especial, 1 part fresh lime juice, 1 part ancho chile-infused simple syrup, 1 float ginger beer, 2 dash angostura bitters',
#  'brisa del sur': '1.5 oz barsol selecto italia pisco, .5 oz rocoto passion fruit reduction, .5 oz fresh lime juice, .5 oz simple syrup',
#  'bubbleliciously delicious': '.5 oz luxardo fernet, 1.5 oz luxardo triplum (triple sec), 1 dash angostura bitters, 2 slices satsuma slices, 2 oz sioux city sarsparilla soda',
#  'bubbly bird': '1 oz pink pigeon rum, 1 fill champagne, 1 dash angostura bitters, 1 dash peach bitters, 1 dash luxardo fernet',
#  'buccaneer': '2 oz junipero gin, .5 oz campari, .5 oz velvet falernum, 1 oz lime juice, .5 oz simple syrup, 3 large chunks pineapple',
#  'buenaventura': '.75 oz barsol primero quebranta pisco, .75 oz el tesoro reposado tequila, .5 oz grüner veltliner, .5 oz lime, .25 oz pineapple gum, 1 bsp sweet marmalade',
#  'bunny poison': '2 oz rhubarb cucumber & mint-infused junipero gin, .75 oz lemon juice, .75 oz tempus fugit alessio vermouth bianco, .5 oz rhubarb juice, .5 oz grapefruit juice, .5 oz rhubarb syrup, 2 dash fee brothers celery bitters',
#  'bushido cocktail': '2 oz nikka whisky taketsuru pure malt 12 yo, .5 oz pedro ximenez sherry, 2 dash angostura bitters',
#  'buster crusta': '2 oz h by hine, 1 oz lemon juice, .75 oz the genuine curacao liqueur orange, .5 oz luxardo maraschino liqueur, .5 oz small hand foods gum syrup, 1 bsp luxardo fernet',
#  "buzzard's bay": '2 part no.3 london dry gin, .5 part real cranberry juice, .25 part luxardo fernet, .5 part lime juice, 1.5 part puer black tea',
#  'cafe creole': '1.5 oz pink pigeon rum, 1 oz luxardo espresso italian liqueur, 1.5 oz heavy cream, .75 oz simple syrup',
#  'caipirinha': '4 pieces lime, 1-2 tbsp sugar, 1 1/2 oz ypiòca',
#  "california's callin'": "1.5 oz junipero gin, .5 oz luxardo maraschino liqueur, 1 oz grapefruit juice, .75 oz lemon juice, 1 dash tempus fugit abbott's bitters,  to fill anchor california lager",
#  'canary vs. the coal mine': '.5 oz old forester bonded bourbon, .5 oz h by hine, 1 oz rock & rye, 1 oz cocchi americano rosa,   activated charcoal',
#  "cap't of the seven seas": '2 oz ypioca brasilizar cachaca ouro reserva especial, 1 oz jalapeno-orange simple syrup, 1 oz coconut milk, 4 dash orange flower water, 9 drops mole bitters',
#  'carrier pigeon (an airmail with pink pigeon)': '1 oz pink pigeon rum, .5 oz lime juice, .5 oz honey',
#  'champs élysées': '2 oz h by hine, .75 oz lemon juice, .5 oz green chartreuse, .25 oz simple syrup, 2 dash angostura bitters',
#  'chapman cobbler': '1 oz applejack, 1 oz amontillado sherry, .75 oz orgeat, .75 oz fresh lemon juice, 1 bsp tempus fugit creme de noyaux',
#  'charente royale': '1.5 oz h by hine, .5 oz elderflower liqueur, 2 dash absinthe,  top sparkling wine',
#  'cherries st. james': '1.5 oz no.3 london dry gin, .25 oz lemon juice, .25 oz pages elderflower syrup, .25 oz luxardo sangue morlacco cherry liqueur, .25 oz luxardo maraschino liqueur',
#  'cherry bark martinez': '2 oz old tom gin, .75 oz carpano antica, 1 spoon luxardo maraschino liqueur, 1 dash angostura bitters, 2 dash bittercube cherry bark bitters',
#  'cherry blossom martini': "2 oz karlsson's gold vodka, 1 oz dolin dry vermouth, .25 oz luxardo maraschino liqueur, 6 dash celery bitters",
#  'cherry champagne cocktail': '4 oz champagne or prosecco, 1 oz tart cherry juice, .5 oz luxardo maraschino liqueur, 4 dash mole bitters, 1 bsp luxardo amaro abano',
#  'cherry old fashioned': '.5 tsp demerara sugar, 1  roasted cherry, 2 oz cherry-infused vodka, .25 tsp amaro di angostura, .25 tsp luxardo maraschino liqueur, 5 dash miracle mile forbidden barrel aged bitters',
#  'cherry orchard': ".5 oz luxardo sangue morlacco cherry liqueur, .25 oz luxardo maraschino liqueur, .5 oz laird's straight bonded , 1.25 oz clear creek kirschwasser eau de vie, .25 oz lemon juice, .5 oz grapefruit juice, .25 oz simple syrup, 2 dash peychaud's bitters",
#  'cherry shandy': '1.5 oz luxardo sangue morlacco cherry liqueur, 6 oz ipa',
#  'chilcano': '2 oz barsol selecto acholado pisco, .5 oz fresh lime juice, 2-3 drops angostura bitters,  top ginger ale',
#  'chilcano (variation)': "1.25 oz barsol primero quebranta pisco, .25 oz king's ginger liqueur, .5 oz fresh lime juice, .25 oz agave nectar, 3-4 drops cranberry bitters, 4 oz ginger beer",
#  'chingerito': '2 oz barsol primero quebranta pisco, 1.5 oz grape juice, 1 oz barsol perfecto amor (aperitif wine), 1 oz fresh pomegranate juice, .75 oz cinnamon syrup, .75 oz fresh lime juice, 4  grapes',
#  'chippendale rosetone': '1.5 part gin, .25 part luxardo apricot liqueur, .75 part casoni 1814, .5 part dry vermouth, 1 part unfiltered apple juice, 1 part fresh lemon juice, .5 part rich simple syrup (2:1), 2 part jasmine green tea',
#  'château montifaud creation': '1.5 oz chateau de montifaud cognac vs, 1 oz lemon juice, .25 oz orgeat (almond) syrup, .25 oz triple sec,  top lemonade',
#  'château montifaud lady touch triple sec': '1.5 oz chateau de montifaud reserve speciale michel vallet, .75 oz triple sec, 1 oz lemon juice, 1 oz sugar syrup, 8  fresh mint,   ice cubes',
#  'château montifaud on mint': '1 coffee spoon sugar syrup, 10  fresh mint, .25  sliced green lemon, 1 oz chateau de montifaud cognac vsop, .75 oz lemon juice, .75 oz sparkling water',
#  'château montifaud on the rocks': '1.5 oz chateau de montifaud cognac xo, 3  ice cubes',
#  'château montifaud pink love': '.75 oz chateau de montifaud xo silver, .75 oz sugar syrup, .75 oz lemon juice, 3  raspberries,  fill champagne',
#  'citrus agave caipirinha': '1.5 oz ypioca brasilizar cachaca prata classica, 1.5 oz citrus agave blend, 1 splash soda water',
#  'citrus quo (adapted)': '1.5 oz no.3 london dry gin, .5 oz luxardo limoncello, .5 oz luxardo aperitivo, 3 oz tonic water',
#  'classic lolita': '2 oz nikka whisky taketsuru, .5 oz okinawa sugar, .5 oz soda, 2 dash orange bitters, 2 dash old fashioned bitters',
#  'clear intentions': '1.5 oz luxardo bitter bianco, .5 oz krogstad aquavit, 1 bsp luxardo apricot liqueur, 1 dash orange cream citrate, 1.25 oz almond cream soda',
#  'clearly bitter': '.75 oz luxardo bitter bianco, 1 oz junipero gin, .75 oz dry vermouth, .5 oz curacao, 2 dash rhubarb bitters',
#  'club med': '.75 oz luxardo apricot liqueur, .75 oz barsol selecto italia pisco, .75 oz elderflower liqueur, 2 oz white dry white(preferably sauvignon), 2 oz club soda',
#  'coco batida': '1 1/2 oz coconut milk, 1 1/2 oz condensed milk, 3 oz ypiòca, 1 tbsp sugar',
#  'coffee & clove': '1.5 oz nikka coffey grain whisky, .75 oz manzanilla sherry, .75 oz orange liqueur, 2 dash clove tincture',
#  'coffey grain manhattan': "2 oz nikka coffey grain whisky, 1 oz tempus fugit alessio vermouth di torino rosso, 1 dash tempus fugit abbott's bitters",
#  'conference': '.5 oz h by hine, .5 oz rye whiskey, .5 oz bourbon, .5 oz calvados, 1 tsp demerara syrup, 2 dash angostura bitters, 1 dash bittermens xocolatl mole bitters',
#  'corpse reviver no 1': '50 ml h by hine, 25 ml calvados, 25 ml tempus fugit alessio vermouth bianco',
#  'corpse reviver no.2': ".75 oz no.3 london dry gin, .75 oz tempus fugit kina l'aero d'or, .75 oz the genuine curacao liqueur clear, .75 oz lemon juice,  rinse vieux pontarlier absinthe francaise superieure",
#  'cosmopolitan': 'absolut citron,lime juice,cointreau,cranberry juice',
#  'cosmopolitan martini': 'cointreau,vodka,lime,cranberry juice',
#  'cream soda': 'spiced rum,ginger ale',
#  'creek ran dry': '1 oz pear brandy, 1 oz dry vermouth, .5 oz chateau de montifaud pineau des charentes blanc, .5 oz dolin genepy',
#  'creole': '1.5 oz h by hine, .75 oz clement creole shrubb, .75 oz fino sherry, 2 dash orange bitters',
#  'creole cobbler': '1 oz junipero gin, 1 1/2 oz sathenay crème de peche, 1/2 oz fresh lemon juice,  oz 2 dashes orange bitters',
#  'creole summer': "1.5 oz vanilla flavored vodka, .75 oz luxardo limoncello, 1 oz fresh sweet n' sour, .5 oz passion fruit puree, .5 oz egg white, 7 dash green tabasco",
#  'croatia firing squad': '1 oz luxardo bitter bianco, 1 oz lillet blanc, 1 oz no.3 london dry gin, .5 oz rose wine',
#  'crooked kilt': '1.5 oz glenrothes vintage reserve, .75 oz lime juice , .5 oz green chartreuse, .5 oz velvet falernum, .5 oz pineapple juice',
#  'cuba liberation': '2 oz pink pigeon rum, 1.5 oz fresh lime juice, .25 oz simple syrup,  oz mexican coca cola, 1 float luxardo fernet',
#  'culebra': '1.5 oz rhum agricole-style, .75 oz luxardo amaretto di saschira, .5 oz fresh lime juice, 4 oz cola, 3 oz mint sprigs, 2 dash bitters',
#  "cupid's carrier pigeon": '1 oz no.3 london dry gin, 1 oz velvet falernum, .75 oz pink pigeon rum, 1 oz unfiltered apple juice, 1 oz lime juice, 3 dash angostura bitters',
#  'cut & rum': '.75 oz banks 5 rum, .75 oz denizen aged white rum\xa0, .75 oz denizen aged white rum\xa0, .75 oz luxardo amaro abano',
#  'cut to the chase': '2 oz j.h. cutter whisky, .75 oz averna amaro, .5 oz alvear px sherry, 2 dash angostura bitters',
#  'daisy mae': '2 oz junipero gin, 1 oz lime juice, .75 oz green chartreuse, .75 oz simple syrup',
#  'dark caipirinha': 'demerara sugar,lime,cachaca',
#  'day for night': '1.5 oz c. drouin calvados selection, .5 oz la quintinye vermouth rouge, .25 oz pedro ximenez sherry, .25 oz cannella cinnamon cordial, 1 dash angostura bitters',
#  'delicious in mauritius': '1.5 oz pink pigeon rum, .5 oz white peach puree, .25 oz hibiscus syrup, .25 oz lemon juice, .5 oz ginger ale',
#  'delicious sour': '2 oz c. drouin calvados selection, .75 oz lemon juice, .75 oz giffard abricot du roussillon, .5 oz egg white',
#  'dernier mot': '.75 oz rhum agricole, .75 oz green chartreuse, .75 oz luxardo maraschino liqueur, .75 oz fresh lime juice',
#  "desmond's choice": '2 oz hirsch small batch reserve bourbon, .5 oz creme de cacao, .25 oz pierre ferrand dry orange curacao, 3 dash the bitter truth jerry thomas bitters',
#  'deviled negroni ': '1 oz no.3 london dry gin, 1 oz maurin quina, 1 oz luxardo bitter',
#  'dirty martini': 'vodka,dry vermouth,olive brine,lemon,olive',
#  'divine aspect': '1 oz no.3 london dry gin, 1 oz apple-infused wild turkey bourbon 101, 1 oz luxardo apricot liqueur',
#  'division bell': '1 oz mezcal, .75 oz aperol, .5 oz luxardo maraschino liqueur, .75 oz lime juice',
#  "doctor's orders": "1.75 oz junipero gin, .75 oz dry vermouth, .25 oz curacao, 1 dash tempus fugit abbott's bitters",
#  "don't rock the boat punch": '1 part no.3 london dry gin, 1 part rooibus tea (steeped and cooled), 1 part mulled cider (cooled), .5 part clover honey syrup, .33 part cava,   angostura',
#  'donaji': '2 oz mezcal, .5 oz fresh lemon juice, .5 oz fresh lime juice, .75 oz agave nectar',
#  'down the rabbit hole': ' oz junipero gin,  oz lemon,  oz elder flower liquor,  oz honey syrup,  oz carrot juice',
#  'drink lab #16': '2 oz brandy, .75 oz orgeat, .75 oz luxardo sangue morlacco cherry liqueur, .5 oz lemon juice, 10 drops bittermens burlesque bitters',
#  'drops of jupiter': '1.5 oz junipero gin, .5 oz genevieve gin, .25 oz rich wild sage honey syrup, 1 dash angostura bitters, 1 dash whiskey barrel aged bitters, .75 oz spring water',
#  'dry mauritian sour': '40 ml pink pigeon rum, 10 ml campari, 10 ml lavender syrup, 10 ml lemon juice , 10 ml orange juice, 25 ml egg white',
#  "duchamp's punch": 'pisco,lime juice,pineapple syrup,st. germain,angostura bitters,pepper,lavender',
#  "duke's classic dry martini": '3 oz no.3 london dry gin, 1 tsp extra dry vermouth, 1  amalfi lemon',
#  'dutch stories': '1.5 oz genevieve gin, .75 oz luxardo apricot liqueur, .25 oz luxardo maraschino liqueur, .5 oz fresh lemon juice, 1 tbsp gooseberry jam',
#  'eat, drink and be cherry': '.75 oz nikka coffey grain whisky, .75 oz luxardo sangue morlacco cherry liqueur, .5 oz mendolera, .5 oz cane sugar, .5 oz lemon, 3 oz fever-tree soda',
#  "eden's apple": "1.5 oz apple & cinnamon-infused karlsson's gold vodka, .75 oz j. t. taylor's falernum, .5 oz fresh lemon juice, 1 oz fresh cider, 1 tincture bar keep baked apple bitters",
#  'el cortez': '1 oz luxardo apricot liqueur, 1.5 oz chinaco reposado tequila, 2 oz dry riesling',
#  'el mustavo': '2 oz mezcal, 1 oz tempus fugit alessio vermouth chinato, 1 oz campari, 2 dash rhubarb bitters, 2 dash orange bitters',
#  'elgin elixir': '1 oz benriach single malt 12 yo, 1 oz c. drouin calvados selection, 1 oz luxardo aperitivo',
#  'end of winter': "2 oz h by hine (brown butter-infused), 0.5 oz king's ginger liqueur, 3 dash fee brothers black walnut bitters",
#  'endless summer': '1.5 oz ypioca brasilizar cachaca prata reserva especial, .75 oz luxardo bitter, .25 oz luxardo maraschino liqueur, .75 oz lemon juice, 1 dash lemon bitters',
#  'english harbour colada': '2 oz english harbour rum 5 yo, 2 oz fresh squeezed pineapple juice, 2 oz fresh coconut water',
#  "erasmus' revenge": '2 oz junipero gin, .5 oz carpano antica, 1 bsp calisaya, 3 dash the bitter truth grapefruit bitters',
#  'espresso martini': 'vodka,kahlua,sugar syrup',
#  'espèce de sazerac': "1 oz h by hine, .5 oz old overholt straight rye whiskey, .5 oz rittenhouse straight rye whisky, 1 bsp rich demerara simple syrup, 3 dash peychaud's bitters",
#  'essence no.5 (adapted)': '1.5 oz no.3 london dry gin, .75 oz luxardo triplum (triple sec), .5 oz lavander syrup, 1 oz fresh lime juice, 4  raspberries',
#  'far from the tree': '1.5 oz c. drouin calvados selection, .75 oz orgeat, .5 oz lemon juice, 1 oz pear & celery puree, .5  egg white',
#  "farmer's gold": "2 oz karlsson's gold vodka, .75 oz fresh lemon juice, 1 oz simple syrup (1:1), 3 dash regans' orange bitters, 5 large basil leaves, 16 whole black peppercorns",
#  'feingold': '2 oz brandy, .5 oz orange cordial, 1 bsp luxardo sangue morlacco cherry liqueur, 1  luxardo cherry (muddled), 1 dash aromatic bitters, 1 dash cherry bitters',
#  'fernet frappe': "1.5 oz luxardo fernet, .5 oz king's ginger liqueur, 2 oz cola, 1 wedge lemon juice",
#  'fiery clydesdale': "1.5 oz pusser's blue label rum\xa0, .5 oz king's ginger liqueur, .5 oz ginger syrup, .25 oz lime juice,  top homemade pink grapefruit soda",
#  'figge bout it': '2 oz westland american single malt, .25 oz lustau pedro ximénez sherry, .75 oz lemon juice, .5 oz fig & cinnamon syrup, 1 dash angostura bitters',
#  'final ward': '.75 oz rye whiskey, .75 oz green chartreuse, .75 oz luxardo maraschino liqueur, .75 oz fresh lemon juice',
#  'fiona graham': '1.5 oz luxardo bitter bianco, 1 oz junmai sake, .25 oz coconut rum, 1 dash orange bitters, 1 dash coconut vinegar',
#  'flambeed brandy alexander': '2 oz h by hine, 1 oz tempus fugit creme de cacao, 1 oz cream (steamed as for a cappuccino)',
#  'flamenco': '1.5 oz lustau amontillado sherry, 1 oz bols genever, .5 oz orange juice, .5 oz lemon juice, .75 oz luxardo orgeat syrup, 2 dash angostura bitters',
#  'flaming lamborghini': "kahlua,sambuca,blue curacao,bailey's irish cream",
#  'flight to peru': '1.5 oz barsol selecto italia pisco, 1 oz fresh grapefruit juice, .25 oz simple syrup, .25 oz luxardo maraschino liqueur, 1 dash chocolate mole bitters',
#  'flip and flight': '30 ml pink pigeon rum, 15 ml dry oloroso sherry, 15 oz grenadine, 1 whole egg,   vanilla-salt spray',
#  'flip the bird': '1.5 oz pink pigeon rum, .75 oz simple syrup, .75 oz cream, .5 oz punt e mes, 1  egg yolk',
#  'floral summer': '1.5 oz no.3 london dry gin, .5 oz honey syrup , .75 oz fresh lemon syrup ,   tarragon leaves,   lavender bitters',
#  'fortune & glory': '1.5 oz chinaco reposado tequila, 1 oz lime juice, .5 oz h by hine, .5 oz small hand foods orgeat, .5 oz falernum, 2 dash mole bitters',
#  'fourth generation': '1.5 oz mezcal, .25 oz luxardo espresso italian liqueur, .75 oz luxardo bitter bianco, 2 dash salted chocolate bitters',
#  'frankie and johnnie': "1 oz king's ginger liqueur, 1 oz c. drouin pommeau de normandie, .5 oz fresh lemon juice, .5 oz fresh orange juice, 1 dash jerry thomas bitters",
#  'french 33': '1.5 oz no.3 london dry gin, .75 oz simple syrup, .75 oz lime juice',
#  'french 75': '.75 oz no.3 london dry gin or h by hine, .75 oz fresh lemon juice, 1 dash simple syrup, 1 float sparkling wine',
#  'french maid': "1.5 oz h by hine, 1 oz house ginger beer, .75 oz lime juice, .75 oz simple syrup, .25 oz john d. taylor's velvet falernum, 3  cucumber wheels, 8  mint leaves, 1  mint sprig",
#  'french martini': 'vodka,raspberry liqueur,pineapple juice',
#  'frisco san': '1.5 oz nikka whisky taketsuru pure malt 12 yo, .75 oz barsol perfecto amor (aperitif wine), .25 oz benedictine, 1 dash angostura bitters',
#  'full of bologna': '1 oz c. drouin calvados selection, 1 oz luxardo amaro abano, .75 oz pear watercress puree, .75 oz lemon juice',
#  'gagliardo': 'peach vodka,lemon juice,galliano,sirup of roses',
#  "garrison's new fashioned": '2 oz garrison brothers flagship bourbon, .5 oz luxardo apricot liqueur, 2 dash australian bitters company aromatic bitters,   lemon peel',
#  'geaux geaux cup': '1 oz junipero gin, 1 oz maurin quina, .5 oz fresh lemon, .5 oz pages elderflower syrup,  top ginger ale',
#  'georgia old fashioned': "2.5 oz nikka coffey grain whisky, .25 oz tippleman's barrel smoked maple syrup, 2 dash regans' orange bitters, 5 dash angostura bitters, 1 disc orange, 1 disc lemon, 1 slice peach",
#  'gin made me do it': '1 oz junipero gin, 1 oz c. drouin calvados selection, 1 oz vermouth del professore, 2 dash angostura bitters, 1 dash st. george absinthe',
#  "gin n' celery": '1.5 oz old tom gin, .75 oz lemon juice, .5 oz small hand foods gum syrup, 7 dash celery bitters, 1 oz tonic water, 1 pinch salt',
#  'gin rickey': 'gin,grenadine,lemon,soda water,lime',
#  'ginger drop': ".5 oz king's ginger liqueur, 1.5 oz momokawa organic junmai ginjo sake, .75 oz lemon juice, .5 oz simple syrup",
#  'ginger pigeon': '1 oz pink pigeon rum, .5 oz luxardo aperitivo, .5 oz simple syrup, .5 oz lemon juice, 1 float ginger beer, 4 pieces chopped pineapple, 3 pieces ginger root',
#  'glimpse of seduction': '.75 oz luxardo maraschino liqueur, .75 oz grapefruit flavored vodka, .5 oz fresh lemon juice, 1 float pomegranate liqueur, 2 scoop lemon sorbet',
#  'goat town swizzle': '1 oz old potrero straight rye whiskey, .5 oz luxardo apricot liqueur, .33 oz luxardo fernet, .75 oz lemon juice, .5 oz homemade orgeat, 4 dash angostura bitters, 3 dash fee bros orange bitters',
#  'gold rush': "3  basil leaves, 1.5 oz karlsson's gold vodka, .75 oz pineapple juice, .5 oz simple syrup, .5 oz sweet vermouth, .5 oz lime juice\xa0, .5 oz egg white, 1 dash angostura bitters",
#  'gold spritz': "1 oz cocchi americano, 1 oz karlsson's gold vodka, 2 oz club soda",
#  'gran classico negroni': '.75 oz tempus fugit gran classico bitter, .75 oz no.3 london dry gin, .75 oz tempus fugit alessio vermouth di torino rosso',
#  'green and gold': "750 ml bottle karlsson's gold vodka, 5 sprigs dill, 2 cloves crushed garlic, 1  lemon peel (white pith removed and julienned), 1 tbsp whole peppercorns",
#  'grey anchor': '2 oz hophead vodka, .75 oz lime juice, .5 oz st. germaine elderflower liqueur, .25 oz luxardo maraschino liqueur, 5 drops bittercube door county hop bitters',
#  'grown-up shirley temple': '1 oz luxardo cherry syrup (from jar of cherries), .25 oz fresh lemon juice (optional), 6 oz soda water',
#  'hanky panky (classic)': '1.5 oz no.3 london dry gin, 1.5 oz tempus fugit alessio vermouth di torino rosso, 2 dash luxardo fernet',
#  "hanny's hot apple toddy": '1.5 oz luxardo amaretto di saschira, 8 oz apple cider,  oz heavy cream,  oz cinnamon',
#  "harms' way": '1 oz luxardo bitter bianco, 1.25 oz blanco tequila, .25 oz d.o.m benedictine, 1 dash bittermens xocolatl mole bitters',
#  'heard it through the grapevine': "1.5 oz h by hine, .75 oz graham's 20 year tawny port, .5 oz tempus fugit kina l'aero d'or, .33 oz velvet falernum, .25 oz benedictine",
#  'heart breaker': '1.5 oz bonded rye, .5 oz luxardo amaro abano, .5 oz punt e mes, 7 dash angostura bitters',
#  'hemingway daiquiri': '1.5 oz pink pigeon rum, .75 oz fresh lime juice, .5 oz fresh grapefruit juice, .5 oz luxardo maraschino liqueur',
#  'hibiscus pisco sour': '2 oz barsol primero quebranta pisco, .75 oz lime juice, .75 oz hibiscus/rose syrup, 1  egg white',
#  'hidarite': '1.5 oz nikka coffey grain whiskey, .75 oz luxardo bitter, .75 oz tempus fugit alessio vermouth di torino rosso, 2 dash chocolate bitters',
#  'hippi hill': "1.5 oz hophead vodka, .75 oz king's ginger liqueur, .5 oz lime juice, .5 oz cranberry juice",
#  'holland house': '1 oz genever, 1 oz luxardo maraschino liqueur, .5 oz dry vermouth, .5 oz lemon juice, .5 oz pineapple gomme syrup',
#  'honey basil smash': '1.5 oz english harbour rum 5 yo, .25 oz honey, 3  lime wedges, 4  basil leaves,  top ginger ale',
#  'hophead dirty martini': '4 oz hophead vodka, .5 oz olive juice, 1 dash dry vermouth',
#  'hophead old fashioned': '2 oz hophead vodka, .25 oz simple syrup, 2 dash angostura bitters, 1 dash fee brothers gin barrel aged bitters',
#  'hopped-up mary': "2 oz hophead vodka, 6 oz tomato juice, 1.5 tsp demitri's bloody mary seasoning, .5 oz fresh lemon juice",
#  'hopped-up mule': "2 oz hophead vodka, .5 oz king's ginger liqueur, .75 oz lime juice,  top ginger beer",
#  'hotaling seaside shandy': '1 oz genevieve gin, 1 bottle lager',
#  'hotaling white manhattan': "2 oz christmas spirit, 1 oz tempus fugit alessio vermouth bianco, .25 oz luxardo triplum (triple sec), 1 dash fee brother's orange bitters",
#  'huntsman': '2 oz pink pigeon rum, 1 cube brown sugar',
#  "i'm only happy when it rains": '1 1/2 oz old potrero straight rye whiskey, 3/4 oz hirsh pinot noir reduction, 1/4 oz luxardo sangue morlacco cherry liqueur, 3/4 oz lemon juice',
#  'imperial cocktail': 'lime juice,gin,aperol',
#  'improved calvados cocktail': '2 oz c. drouin calvados selection, 1 bsp benedictine, 1 bsp green chartreuse, 1 bsp small hand foods gum syrup, 2 dash angostura bitters',
#  'improved whisky cocktail': '2 oz nikka whisky taketsuru pure malt 12 yo, 1 dash luxardo maraschino liqueur, 1 dash pontarlier anis',
#  'in hinesight': '1.5 oz h by hine, 1 oz luxardo bitter, .5 oz quady muscat wine',
#  'international mistress': '1.5 oz amaro nonino quintessentia, .75 oz lemon juice, .5 oz mezcal, .5 oz small hand foods orgeat, 2 oz soda water',
#  'ipa mule': '1.5 oz hophead vodka, .5 oz ginger liqueur, .75 oz lime juice, .5 oz pure cane simple syrup, 2 count deschutes fresh squeezed ipa (from tap)',
#  'irish curdling cow': "bailey's irish cream,bourbon,vodka,orange juice",
#  'irish goodbye': '1.5 oz nikka coffey grain whisky, .25 oz absinthe, 4 oz hot coffee, 2-3 oz homemade irish cream',
#  'iron fist in a velvet glove': '1.25 oz lillet rose, .75 oz barsol primero quebranta pisco, .75 oz prata cachaca, .25 oz velvet falernum',
#  'iron tonic': '.75 oz luxardo maraschino liqueur, .75 oz genepy, .75 oz luxardo fernet, .75 oz lime juice, 1 float tonic water',
#  'italian margarita': '1.5 oz maestro dobel diamante tequila, .5 oz luxardo amaretto di saschira, 1 oz fresh lime juice, .25 oz monin cane syrup',
#  'italian riviera mojito': '1 oz coconut rum, .5 oz funkin passion fruit puree, .5 oz briottet creme de banane, .5 oz fresh squeezed lime, 8 leaves mint leaves',
#  'jalapeño sour': '2 oz chinaco blanco tequila, .5 oz green chartreuse, .5 oz lime juice, 1 oz pineapple juice, .5 oz jalapeño syrup, .5 oz egg white',
#  'jammie dodger fizz': '2 oz h by hine, .5 oz tempus fugit creme de noyaux, .5 oz orgeat, .375 oz lemon, .375 oz lime, 1 oz heavy whipping cream, 1  egg white',
#  'japanese cocktail': '2 oz h by hine, .5 oz luxardo orgeat syrup, 3 dash angostura bitters',
#  'japonais no.3': "1.5 oz no.3 london dry gin, 1 oz king's ginger liqueur, 1 oz orange juice, 1 dash simple syrup, 2  cucumber slices, muddled, 2  raspberries, muddled",
#  'jitterbug': 'gin,vodka,grenadine,lime juice,sugar,sugar syrup,soda water',
#  "julia's child": "1 oz broker's gin, 1 oz karlsson's gold vodka, 2 oz celery root puree, .5 oz fresh lemon juice, .75 oz simple syrup, 3 dash apple bitters, 1 dash angostura bitters",
#  'juniperotivo': '1.5 oz junipero gin, .5 oz simple syrup, .5 oz lime juice, .25 oz pomegranate syrup, 4 large mint leaves',
#  'kanazawa': '2 oz nikka coffey grain whisky, .75 oz dry vermouth, .25 oz luxardo amaro abano, 1 bsp luxardo maraschino liqueur, 1 dash angostura bitters',
#  "karlsson's mule": "1.5 oz karlsson's gold vodka, .25 oz lime juice , 3 oz ginger beer",
#  "karlsson's old fashioned": "2 oz karlsson's gold vodka, 1 cube brown sugar, 1 splash bitter",
#  "karlsson's winter punch": "750 ml bottle karlsson's gold vodka, 5 oz pomegranate juice, 9 oz cranberry juice, 9 oz aperol, 4 oz simple syrup (equal parts sugar and water), 3  star anise, 5  cloves, 4  allspice berries, 3  cinnamon sticks, 2 oz orange peel",
#  'kay pacha mi pacha': '1.5 oz barsol supremo moste verde italia pisco, .5 oz no.3 london dry gin, .5 oz luxardo maraschino liqueur, .5 oz lemon juice, 2 dash angostura orange bitters',
#  'kentucky likker': '1.5 oz hirsch small batch reserve bourbon, 1 oz luxardo amaro abano, 2 dash orange bitters, 1 splash club soda',
#  'kentucky mai tai': '1 oz mezcal, 1 oz bourbon, .5 oz lemon, .5 oz peche de vigne, .5 oz cynar, .5 oz orgeat, 4 dash angostura bitters',
#  'kick the pigeon': ' oz pink pigeon rum,  oz st. germaine elderflower liqueur,  oz lemon ,  oz vanilla syrup,  oz prosecco',
#  'kind of fancy': '1.5 oz h by hine, .75 oz wild turkey 101 rye, .5 oz bin 27 port, .25 oz yellow chartreuse, 2 dash mole bitters',
#  "king's medicine": "1.5 oz king's ginger liqueur, .75 oz lemon juice, .5 oz luxardo fernet, .25 oz benriach curiositas single malt 10 yo",
#  "king's snap the chocolate out of you": "1 oz king's ginger liqueur, 1.5 oz homemade milk chocolate, .75 oz hazelnut cinnamon syrup,  oz marshmallow whip cream,  oz ginger snaps",
#  "king's toddy": "1 oz no.3 london dry gin, .75 oz lemon juice, .5 oz king's ginger liqueur, .5 oz clover honey syrup",
#  'kir': '1 part briottet creme de cassis, 4 part chilled dry white wine',
#  'kir royale': '1 part briottet creme de cassis, 4 part chilled dry champagne',
#  'kiss': '2 oz gin, .75 oz sweet vermouth, .75 oz dubonnet rouge, .25 oz luxardo maraschino liqueur',
#  'kiss of persuasion': '1 oz luxardo maraschino liqueur, 1 oz honey-pear liqueur, .5 oz heavy cream,  oz pinch of cardamom,  oz dehydrated pear slice',
#  'knockemdown key': '2 oz english harbour rum, .5 oz briottet creme de banane, .25 oz luxardo maraschino liqueur, .5 oz lime juice, 1 bsp rich simple syrup',
#  'kumquat smash': '1 oz luxardo triplum (triple sec), 1 oz ypioca brasilizar cachaca prata classica, .5 oz luxardo sour cherry syrup (previously amarena), 5  kumquats, 1 float mango flavored rum',
#  "l'aviation": '1.5 oz no.3 london dry gin, 0.5 oz luxardo maraschino liqueur, 0.5 oz tempus fugit liqueur de violettes, .75 oz fresh lemon juice',
#  'l.e.s. is more': "1.5 oz karlsson's gold vodka, .75 oz esprit de june, .5 oz fresh lemon juice, .5 oz simple syrup",
#  'la capilla': '1.5 oz mezcal, .75 oz pierre ferrand curaçao, .5 oz gordy’s cocktail pickle brine, 1 oz watermelon juice, .5 oz fresh grapefruit juice, .5 oz fresh lime juice',
#  'la chiara': '1 oz luxardo bitter bianco, 1 oz barsol primero quebranta pisco, 2 oz fever-tree indian tonic, 1 dash luxardo maraschino liqueur',
#  'la hops vie': '2 oz hophead vodka, .75 oz fresh lemon juice, .75 oz fresh grapefruit juice, .5 oz simple syrup,   gin barrel aged orange bitters,   fresh basil leaves',
#  'la la land': "1.5 oz karlsson's gold vodka, .5 oz aperol, .5 oz raspberry/white pepper syrup, .5 oz fresh lemon juice, .5 oz fresh cucumber juice, 4-5 pc fresh mint, 2 dashes celery bitters",
#  'la madrugada': '1.5 oz barsol perfecto amor (aperitif wine), .5 oz lemon juice, .5 oz luxardo amaro abano, .25 oz luxardo maraschino liqueur',
#  'la maracuja': '2 oz ypioca brasilizar cachaca prata reserva especial, 1.5 oz fresh passion fruit, 1 oz condense milk, .25 oz brown sugar syrup (2:1)',
#  'la nueva moda (the new fashion)': '2 oz chinaco anejo tequila, .25 oz mezcal, .25 oz luxardo maraschino liqueur, 2 drops agave nectar, 3 dash fee brothers aztec chocolate bitters, 2 cubes sugar',
#  'last samurai': '1 oz vodka, 1 oz gin, 1 oz luxardo maraschino liqueur, .5 oz cointreau',
#  'last word': '.75 oz luxardo maraschino liqueur, .75 oz junipero gin, .75 oz green chartreuse, .75 oz fresh lime juice',
#  'le femme nikita': '2 oz nikka whisky taketsuru pure malt 12 yo, .25 oz rich cane syrup, 2 dash bittermens xocolatl mole bitters, 2 dash cinnamon bitters',
#  'le sang et sable': '1.5 oz h by hine, .5 oz dubonnet rouge, .5 oz cherry herring, .375 oz blood orange juice, .375 oz lemon juice',
#  'lemon drop': 'absolut vodka,cointreau,lemon',
#  'little ground tapper': '2 oz h by hine, .25 oz small hand foods pineapple gum syrup, 1 bsp luxardo maraschino liqueur, 2 dash angostura bitters',
#  'local edition punch': "12 bottles h by hine, 4 bottles luxardo apricot liqueur, 1 bottle king's ginger liqueur, 1 bottle luxardo aperitivo, 4 bottles lemon juice",
#  'lonesome george': '1.25 oz apricot-infused h by hine, 1 oz napoleon amontillado, .25 oz mandarine napoléon, .5 oz lazzaroni amaro',
#  'long division': '1.5 oz tequila, 1 oz luxardo maraschino liqueur, .5 oz aperol, .25 oz lime juice',
#  'long island limoncello martini': "1 oz hangar 1 buddha's hand citron vodka, 1 oz luxardo limoncello, .75 oz fresh lemon juice, .25 oz monin cane syrup",
#  'lost at sea': "2 oz king's ginger liqueur, 1 oz lime juice, .5 oz cane sugar syrup, 2 oz club soda",
#  'lovage in the garden': '2 oz hophead vodka, 3  sun gold cherry tomatoes, 4  lovage leaves, .75 oz lime juice, .5 oz agave syrup (1:1 agave to water), .5 oz luxardo aperitivo, 1 pinch hepps ghost pepper salt',
#  'lux cherry sparkler': '1 oz luxardo sangue morlacco cherry liqueur, 4 oz prosecco',
#  'lux japanese lemonade': '1.5 oz no.3 london dry gin, .5 oz jummai ginjo sake, .25 oz luxardo limoncello, .25 oz dill cordial, .5 oz meyer lemon juice, .25 oz yuzu juice, .5 oz fresh egg white',
#  'lux orchard lemonade': '.75 oz luxardo maraschino liqueur, .5 oz junipero gin, .75 oz monin apple puree, .25 oz lemon juice, 1 dash fennel bitters',
#  'lux shandy': '1 oz luxardo aperitivo, .5 oz lemon juice, .5 oz orange juice, .5 oz simple syrup,  top anchor california lager',
#  'luxardo fresco': '1.5 oz luxardo maraschino liqueur, 1 strip cucumber, 1 dash lemon juice,  top tonic',
#  'luxardo ice cream float': '1 oz luxardo cherry syrup (from jar of cherries), 1 scoop vanilla ice cream,  top soda water',
#  'luxardo maraschino simple spritz': '.5 oz luxardo maraschino liqueur, .5 oz squeeze of lime , 3 oz italian sparkling water',
#  'luxardo sling': '.25 oz luxardo sangue morlacco cherry liqueur, .5 oz no.3 london dry gin, .25 oz grapefruit juice, 1 fill soda water',
#  'luxardo sour': '1.25 oz luxardo amaretto di saschira, 1 oz rye whiskey, 1 oz lemon juice, .75 oz angostura bitters, 1  egg white',
#  'malibu twister': 'malibu rum,tropicana,cranberry juice',
#  'mandrake': '1.5 oz barsol primero quebranta pisco, 1 oz barsol perfecto amor (aperitif wine), .25 oz leopold bros. bitter, .25 oz velvet falernum,   red hawaiian salt',
#  'manhattan': "2 oz rye or bourbon whiskey, 1 oz tempus fugit spirits alessio vermouth di torino, 2 dash tempus fugit abbott's bitters",
#  'maraschino side car': '.75 oz luxardo maraschino liqueur, .25 oz dry curacao, .5 oz bourbon rye, .25 oz lemon juice',
#  'marchesa': '30 ml luxardo maraschino liqueur, 20 ml bitter, 20 ml luxardo sangue morlacco cherry liqueur, 20 ml bourbon, 2 dash chocolate bitters',
#  'maria canevari punch': '.5 oz luxardo maraschino liqueur, .75 oz luxardo apricot liqueur, 1 oz fresh lemon juice, .25 oz simple syrup, 1 oz perfect puree white peach, 3 oz soda water',
#  'martinez': '2 oz old tom gin, .75 oz tempus fugit alessio vermouth di torino rosso, .25 oz luxardo maraschino liqueur, 2 dash orange bitters',
#  'martinez cocktail': 'gin,dry vermouth,triple sec,orange bitters,cherry',
#  'martini': 'gin,dry vermouth,olive',
#  'mary pickford': 'light rum,pineapple juice,maraschino liqueur,grenadine,maraschino cherry',
#  "masataka's vision": '2 oz nikka whisky taketsuru pure malt 12 yo, .5 oz luxardo amaro abano, 3 dash house-made rasta bitters',
#  'mauritian buck': '40 ml pink pigeon rum, 40 ml pressed apple juice,   ginger ale,   absinthe,   lemon zest',
#  'mauritian made': '1.5 oz pink pigeon rum, .75 oz darjeeling simple syrup, 1 oz lime juice',
#  'mauritius sour': '.75 oz pink pigeon rum, .75 oz hirsch small batch reserve bourbon, .5 oz angostura bitters, .75 oz lemon juice, .75 oz simple syrup',
#  "mayahuel's revenge": '1.5 oz chinaco blanco tequila, 1 oz vermut vermouth, .5 oz giffard banane du brésil, 3 dash bittercube jamaican #2 bitters',
#  'mayan decadence': '1.75 oz chinaco anejo tequila, .5 oz xtabentun liqueur (honey, anis), 3 dash bittermens xocolatl mole bitters, 3 dash fee brothers aztec chocolate bitters',
#  'mayan mule': ".5 oz king's ginger liqueur, .5 oz ancho reyes chile liqueur, .5 oz montelobos mezcal, .5 oz aviation gin, .5 oz grapefruit juice, .5 oz lime juice, 2 dash bittercube bitters jamaican #2, 2 oz fever-tree ginger beer",
#  'mayan sacrifice champagne cocktail': ".5 oz chinaco blanco tequila, .5 oz d'aristi xtabentun honey liqueur",
#  'mean martinez': '1.5 oz old tom gin, 1 oz lustau east india solera, .5 oz grand poppy liqueur',
#  'merry sherry cobbler': "1.5 oz christmas spirit, 1 oz oloroso sherry, .25 oz walnut liqueur, 3 dash regans' orange bitters, 3 dash pear bitters",
#  'mexican sazerac': "2 oz chinaco reposado tequila, .75 oz d'aristi xtabentun honey liqueur, 3 dash peychaud's bitters",
#  'mexico mule': "1 oz montelobos mezcal, .67 oz king's ginger liqueur, .5 oz fresh lime juice, 3 oz apple cider, .5 oz monin french raspberry syrup",
#  'mezcal witch': '2 oz mezcal, .75 oz lime, .75 oz strega, .75 oz simple syrup, 3-4  cucumbers muddled, 3-4  mint leaves, 1 pinch salt',
#  'miami vice': '151 proof rum,pina colada mix,daiquiri mix',
#  'midnight mint': "bailey's irish cream,white creme de menthe,cream",
#  'mille miglia': '.75 oz luxardo maraschino liqueur, .5 oz luxardo sangue morlacco cherry liqueur, 1  basil leaf, .25 oz lime juice, 5 dash rose water',
#  'mint garden': '1.5 oz chinaco reposado tequila, .5 oz luxardo triplum (triple sec), .75 oz fresh grapefruit juice, .5 oz lemon juice, .5 oz simple syrup, 4 pieces red bell pepper, 4 oz mint sprigs',
#  'mister gingy': "1 oz king's ginger liqueur, 1 oz glenrothes vintage reserve, .75 oz pineapple gum, .75 oz lemon juice, 2 dash angostura bitters",
#  'miyagikyo kick': '1.5 oz nikka whisky miyagikyo single malt 12 yo, .75 oz rare wine co. charleston sercial madeira, .75 oz fresh lime juice, .625 oz small hands food orgeat',
#  'mojito': 'light rum,lime,sugar,mint,soda water',
#  'mojito #3': 'mint,lemon juice,dark rum,club soda,angostura bitters',
#  'monet': '1.75 oz h by hine, 1 oz benriach madeira 15 yo, .5 oz lemon juice, .25 oz briottet creme de banane, .25 oz small hand foods pineapple gum syrup',
#  'monkey gland': '2 oz no.3 london dry gin, 1 oz orange juice, .25 oz grenadine, 1 dash duplais swiss absinthe blanche',
#  'morlacco julep': '1.25 oz brandy de jerez, .75 oz luxardo sangue morlacco cherry liqueur, 4 sprigs mint, 1 float luxardo amaretto di saschira',
#  'mott and mulberry': '1 oz luxardo amaro abano, 1 oz old overholt rye, .5 oz demerara simple syrup (1:1), .5 oz lemon juice, .75 oz fuji apple cider',
#  'muddled mission': '1.5 oz junipero gin, 1 oz st. germain, .25 oz yellow chartreuse, .75 oz lemon juice, 1  strawberry',
#  'mule pigeon': '40 ml pink pigeon rum, 2 dash angostura bitters,  top ginger beer',
#  'mystique green (adapted)': '1.5 oz no.3 london dry gin, .75 oz luxardo triplum (triple sec), .75 oz elderflower liqueur, 1 oz fresh lime juice, .5  kiwi',
#  'nara mule': "2  kumquats, 2  lychee, 2 oz bulleit rye, 1 oz king's ginger liqueur, .75 oz fresh lemon juice, .5 oz simple syrup, .5 oz egg white, .5 oz fever tree ginger beer",
#  'naughty nikka': '2 oz nikka whisky taketsuru pure malt 12 yo, 1 oz fresh ginger syrup, 1 slice orange slice, 1 dash chinese five spice bitters',
#  'negroni': '1 oz no.3 london dry gin, 1 oz tempus fugit alessio vermouth di torino rosso, 1 oz luxardo bitter',
#  "negroni d'amore": "1.5 oz old tom gin, 1 oz barolo chinato, 1 oz tempus fugit kina l'aero d'or",
#  'negroni sorbetto': '.5 oz junipero gin, .5 oz luxardo bitter, .5 oz tempus fugit alessio vermouth bianco, .5 oz dry vermouth, 1 scoop orange sorbet, 2 drops bittermens orange cream citrate',
#  'neighborhood negroni': '1 oz junipero gin, 1 oz campari, 1 oz tempus fugit alessio vermouth di torino rosso',
#  'neko colada': '1 oz miso washed white rhum agricole, 1 oz cocchi vermouth di torino, .75 oz falernum, .75 oz coconut cream, .25 oz luxardo amaretto di saschira, .75 oz lime, .5 oz mandarin orange',
# ...
#  'the asterisk': '.75 oz brandy, .75 oz green chartreuse, .75 oz luxardo maraschino liqueur, .75 oz lemon juice',
#  'the awen': '1.5 oz pot still-style irish whiskey, .5 oz luxardo maraschino liqueur, 1 oz cocchi americano, 1 dash orange bitters',
#  'the bacchus cocktail': '5  concord grapes, 3  blackberries, 1.5 oz barsol primero quebranta pisco, 1 oz crème yvette, 1 oz lemon juice, .5 oz egg white',
#  'the big picture': '1.5 oz tempus fugit alessio vino chinato, 1.5 oz fig-infused c. drouin calvados selection, .5 oz lemon, .25 oz simple syrup',
#  'the bitter king': "2 oz king's ginger liqueur, .75 oz lemon juice, .75 oz simple syrup",
#  'the bittered valley': "1.25 oz luxardo maraschino liqueur, 4 drops acid phosphate, 2 oz barsol primero quebranta pisco, .75 oz luxardo amaro abano, .25 oz luxardo fernet, 3 dash scrappy's aromatic bitters",
#  'the boys of summer cup': "1 oz no.3 london dry gin, 1 oz dolin rouge vermouth, .5 oz the genuine curacao liqueur orange, .5 oz king's ginger liqueur, .25 oz chareau liqueur, .5 oz fresh lemon juice,  top fever-tree bitter lemon",
#  'the brightside': '1.5 oz pink pigeon rum, 2.5 oz fresh orange juice, 1 tbsp luxardo bitter, 1 dash milk powder (or cream)',
#  'the canevari cocktail': '1.5 oz old tom gin, 1 oz cocchi vermouth di torino, .5 oz luxardo bitter, 3 dash angostura bitters',
#  'the cappa': '1.5 oz gin, 1.5 oz pineau des charentes, .5 oz luxardo maraschino liqueur',
#  'the cavalier white lady': '1 oz junipero gin, .75 oz creole shrub, .75 oz lemon juice, .25 oz lemon bitters, .5 oz simple syrup, 1  egg white',
#  'the chief': '1.5 oz junipero gin, .75 oz cocchi americano, .5 oz salers gentiane aperitif, 2 drops black licorice-infused angostura bitters, 1 drop sea salt tincture',
#  'the claridge': '2.25 oz gin, 2.25 oz dry vermouth, .75 oz luxardo apricot liqueur, .75 oz cointreau',
#  'the cliffdiver': "1.25 oz d'aristi 10 yr rum, .5 oz the genuine curacao liqueur blue, .25 oz tempus fugit liqueur de violettes, 1 oz lime juice, .5 oz tahitian vanilla bean syrup, 1 float ginger beer, 3 dash angostura bitters",
#  "the commissioner's trophy #3": '1.5 oz no.3 london dry gin, 1 oz amaro, .5 oz barsol perfecto amor (aperitif wine), .5 oz strawberry shrub',
#  'the double crown': "1.25 oz compass box great king street glasgow blend, .75 oz lemon juice, .5 oz cyril zangs double zero eau de vie de cidre, .5 oz king's ginger liqueur, .5 oz honey syrup, 1  egg white",
#  'the douglas tilden': '2 oz junipero gin, .5 oz lacuesta blanco vermouth, .25 oz salers gentiane aperitif, 1 bsp luxardo maraschino liqueur, 1 bsp germain-robin absinthe, 2 dash scrappy’s lime bitters',
#  'the evil blue thing': 'creme de cacao,blue curacao,light rum',
#  'the french connection': '2 oz h by hine, 1 oz fresh lemon juice, 1 oz demarara simple syrup, 4 dash apple bitters',
#  'the fritz': ".75 oz junipero gin, .75 oz luxardo maraschino liqueur, .75 oz peychaud's bitters, .75 oz punt e mes",
#  'the ginger royale': "35 ml king's ginger liqueur, 140 ml champagne",
#  'the hollinger manhattan': '2 oz rittenhouse rye, .5 oz sweet vermouth, .25 oz luxardo maraschino liqueur, .25 oz duplais swiss absinthe verte',
#  'the house of duncan': "1.5 oz glenrothes vintage reserve, .5 oz luxardo sangue morlacco cherry liqueur, .25 oz king's ginger liqueur, 1 dash angostura bitters",
#  'the improved sazerac': "1.5 oz h by hine, .25 oz luxardo maraschino liqueur, .5 tsp simple syrup (1:1), 3 dash peychaud's bitters, 1 dash angostura bitters,  rinse vieux pontarlier absinthe francaise superieure",
#  'the inside job': '2 oz bourbon, .25 oz luxardo maraschino liqueur, .5 oz simple syrup, 1 dash angostura bitters, 1 dash vieux pontarlier absinthe francaise superieure',
#  'the king and tonic': "1.5 oz king's ginger liqueur, 3 oz fever-tree tonic water, 1 dash angostura bitters",
#  'the king merlet sidecar': "1.5 oz h by hine, .5 oz luxardo triplum (triple sec), .5 oz king's ginger liqueur, .5 oz fresh lemon juice, 1 oz pressed apple juice",
#  "the king's autumn cobbler": "1 oz king's ginger liqueur, .25 oz briottet creme de mure (blackberry),  top pear cider",
#  "the king's cranberry sauce": "1 pkg, 14 oz cranberries, 1.5 c brown sugar, .5 c orange juice, .3 c king's ginger liqueur, 8 whole pepper corns, 6  allspice berries, 5  cloves, 1 stick, 2 in cinnamon",
#  "the king's egg nog": "1 oz no.3 london dry gin, .5 oz king's ginger liqueur, .25 oz english harbour rum, 3 spoon sugar, 1 whole egg, .5 oz milk, .5 oz cream",
#  "the king's froth & frizz": "1 oz barsol selecto italia pisco, 1.25 oz king's ginger liqueur, .5 oz peach brandy, .5 oz lemon juice, .5 oz egg white",
#  "the king's ginger spiced punch": "25 oz king's ginger liqueur, 37.5 oz cranberry juice, 37.5 oz fever-tree lemonade",
#  "the king's ginger summer cup": "1 oz king's ginger liqueur, 1.5 oz cranberry juice, 1.5 oz fever-tree lemonade",
#  "the king's medicine": "1.5 oz king's ginger liqueur, .5 oz luxardo fernet, .25 oz benriach curiositas single malt 10 yo, .75 oz lemon juice",
#  "the king's mulled cider": "2 oz king's ginger liqueur, 5 oz hard apple cider, 5 oz fresh apple juice",
#  "the king's mulled wine": "1 bottle red wine, .3 bottle king's ginger liqueur, 3 tbsp caster sugar, 2  lemons, zested (plus flesh of one lemon), 1  orange, zested, 1 stick cinnamon, 1 dash nutmeg, 1  star anise",
#  "the king's queen": "50 ml king's ginger liqueur, 25 ml fresh lime, 1 slice fresh ginger, 4 strawberries strawberries(muddled)",
#  "the king's spring daisy": "1 oz king's ginger liqueur, 1 oz h by hine, .25 oz lemon juice, .25 oz simple syrup, 2 dash fee brothers rhubard bitters",
#  "the king's squeeze": "35 ml king's ginger liqueur, 125 ml fever-tree bitter lemon",
#  "the king's winter cup": "1.5 oz king's ginger liqueur, 1 oz fresh pressed apple cider, 4 oz hard apple cider, 1 stick cinnamon stick",
#  'the kings mule': "1 oz king's ginger liqueur, 3 dash orange bitters, 5 oz sparkling wine",
#  'the lady whisper': '1 oz aged rum, 1 oz old potrero straight rye whiskey, .5 oz luxardo apricot liqueur, .5 oz luxardo sangue morlacco cherry liqueur, 2 dash bitters',
#  'the ladybird': '2 oz pink pigeon rum, 2 dash fee brothers black walnut bitters, .5 oz luxardo sangue morlacco cherry liqueur, .5 oz luxardo fernet',
#  'the last marasca': '50 ml gin, 20 ml luxardo maraschino liqueur, 5 ml luxardo orgeat syrup, 5 ml lemon juice, 1 dash absinthe',
#  'the last wish': '1 oz luxardo amaro abano, 1 oz luxardo amaretto di saschira, 2 oz espresso coffee, 1 scoop vanilla ice cream',
#  "the lover's quarrel ": "1 oz no.3 london dry gin, 1 oz maurin quina, .75 oz king's ginger liqueur, .5 oz honey jalapeño syrup, 1 oz orange juice, .5 oz lemon juice, 1 oz soda water",
#  'the mad king': "2 oz glenrothes vintage reserve, 1 oz king's ginger liqueur, .25 oz honey syrup, 1 dash angostura bitters",
#  'the mayan premonition': '1.5 oz chinaco blanco tequila, .75 oz luxardo sangue morlacco cherry liqueur, .5 oz fresh lime juice, 1 float bitter lemon soda',
#  'the molino': '1.5 oz bourbon, .5 oz luxardo amaretto di saschira, .5 oz demerara syrup (1:1), .75 oz lemon juice, 1  egg white',
#  'the monte rua': "4 oz ca' secco sparkling, 1 bsp luxardo cherry syrup",
#  'the no.3 winter cup': "25 ml no.3 london dry gin, 25 ml king's ginger liqueur, 12.5 ml red vermouth (antica formula), 150 ml good quality sharp lemonade",
#  'the no.3 winter punch': "1 part no.3 london dry gin, 1 part king's ginger liqueur, .5 part red vermouth (antica formula), 6 part good quality sharp lemonade",
#  'the palace cellar': "1.5 oz king's ginger liqueur, .5 oz pink pigeon rum, .5 oz fresh-pressed lemon juice, .5 oz snake oil's house-made sarsaparilla syrup, .75 oz carbonated water, 1 dash snake oil's house-made pomegranate bitters",
#  'the pink aperitivo': "30 ml pink pigeon rum, 15 ml luxardo aperitivo, 15 ml red vermouth, 2 dash peychaud's bitters",
#  'the pink pussycat': '1.5 oz pink pigeon rum, .5 oz fair goji berry liqueur, .5 oz noyeau de poissy  b, .5 oz cream, 5 dash chocolate bitters',
#  'the professor': '1.5 oz nikka coffey grain whisky, .75 oz madeira, .75 oz dolin dry vermouth, .25 oz nux alpina walnut nocino liqueur, 1 dash angostura bitters',
#  'the proverb': '2 oz h by hine, .5 oz maurin quina, .25 oz luxardo maraschino liqueur, 1 dash angostura bitters, 2 dash black walnut bitters',
#  "the queen's a redhead": "50 ml king's ginger liqueur, 4  pink peppercorns, 25 ml fresh lemon juice, 15 ml gomme syrup, 25 ml egg white",
#  'the red anchor': "1.75 oz junipero gin, .75 oz lemon juice, .5 oz grapefruit juice, .5 oz tempus fugit kina l'aero d'or, .25 oz ginger syrup, .25 oz simple syrup (1.5 : 1)",
#  'the reserved king': "2.5 oz glenrothes vintage reserve, .5 oz king's ginger liqueur, 3-4 dash angostura bitters,   lemon peel",
#  'the rickenbacker': '2 oz hophead vodka, 1 oz tempus fugit alessio vermouth bianco, 2 dash luxardo maraschino liqueur,   salt',
#  'the robert baratheon': '2 oz single malt scotch, .25 oz dry vermouth, .25 oz luxardo maraschino liqueur, 2 dash angostura bitters',
#  'the royal buck': "1 oz no.3 london dry gin, 1 oz king's ginger liqueur, .75 oz lemon juice, .5 oz simple syrup, 2 oz club soda",
#  'the royal king': "1 oz king's ginger liqueur, 4 oz champagne",
#  'the rusty tack': "1 oz king's ginger liqueur, 1 oz glenrothes vintage reserve",
#  'the seniorita': '1.5 oz the genuine curacao liqueur orange, .5 oz lime juice, 1.5 oz thai coconut milk, 2 dash angostura bitters, 1 float gosslings 151 rum',
#  'the silver cocktail': '1.5 oz junipero gin, 1.5 oz dry vermouth, .25 oz luxardo maraschino liqueur, 2 dash orange bitters',
#  'the sixth sense': '1 oz junipero gin, 1 oz luxardo amaro abano, 1.5 oz cream of coconut, .5 oz fresh pineapple juice, .5 oz fresh lime juice, 3 dashes angostura bitters',
#  'the southside': '2 oz no.3 london dry gin, 1 oz fresh lemon juice, 1 oz simple syrup, 5 leaves mint leaves',
#  'the sparkler': '.75 oz luxardo bitter bianco, .75 oz dolin blanc, 2.5 oz prosecco',
#  'the stand by': "2 oz junipero gin, .5 oz luxardo bitter, 1 bsp kalani coconut liqueur, 1 dash angostura bitters, 1 dash peychaud's bitters",
#  'the sun also rises': '2 oz banks 5 island rum, .75 oz fresh lime juice, .5 oz fresh grapefruit juice, .5 oz luxardo maraschino liqueur, 1 tsp vieux pontarlier absinthe francaise superieure',
#  'the tahoe toddy': "2 oz hot water, 2 oz glenrothes, 1 oz king's ginger liqueur, 1 dash honey",
#  'the touch  of glass': '1.5 oz brandy de jerez (foie gras-infused), 2-3 drops truffle tincture,   atomized pipe tobacco essence',
#  'the twinger ': "1.5 oz king's ginger liqueur,  top fever-tree ginger ale, 2 dash angostura bitters",
#  'the windtalker': "1.5 oz hirsch small batch reserve bourbon, .75 oz luxardo amaretto di saschira, .5 oz king's ginger liqueur, .75 oz fresh lemon juice, .5 oz egg white",
#  'three flips': '1.5 oz no.3 london dry gin, 1.5 oz averna, .75 oz honey, 1 whole egg',
#  'thyme for bed': '1.5 oz chamucos blanco tequila, .5 oz luxardo sangue morlacco cherry liqueur, .5 oz thyme simple syrup, .5 oz lime juice',
#  'toasted drop': "1.5 oz citrus-flavored vodka, .75 oz luxardo limoncello, .5 oz luxardo amaretto di saschira, 1 oz fresh sweet n' sour, .5 oz egg white",
#  'tokyo tea': '1.5 oz nikka coffey grain whisky, 1 oz yogurt liquor, .5 oz milk, .5 oz golden sesame honey, 1 dash angostura bitters, 1 tsp matcha tea',
#  'trip to jarnac': '1 oz h by hine, .5 oz orange juice, .75 oz lemon juice, .25 oz batavia arrack, .5 oz simple syrup, 1 dash angostura bitters',
#  'tropical bronzer': "1.5 oz aged rum, 1 oz luxardo amaretto di saschira, 1 oz passion fruit puree, 2 oz fresh lime sweet n' sour, 2 dash bitters, 1 float coconut foam",
#  'under the sun': '1.5 oz plantation pineapple rum, 1 oz barsol perfecto amor (aperitif wine), .5 oz ancho reyes, 3 dash house-made roasted banana bitters',
#  'venetian': '.5 oz luxardo amaretto di saschira, .5 oz campari, .5 oz dry vermouth',
#  'vesper': "2.25 oz no.3 london dry gin, .75 oz hophead vodka, .5 oz tempus fugit kina l'aero d'or",
#  "vesper's sister": '1 oz van gogh blue vodka, 1 oz no.3 london dry gin, .5 oz lillet blanc, .25 oz st. germain',
#  'vida verde (adapted)': "1.5 oz chinaco blanco tequila, .75 oz luxardo maraschino liqueur, 1.5 oz lime sweet n' sour mix,  oz cucumber wheels,  oz sprigs of mint",
#  'vieux carré': ".75 oz rye whiskey, .75 oz h by hine, .75 oz tempus fugit alessio vermouth bianco, 1 bsp benedictine, 2 dash angostura bitters, 2 dash peychaud's bitters",
#  'vintage reserve sour': '1.5 oz glenrothes vintage reserve, .5 oz lemon juice, 1 dash simple syrup',
#  'vinterpäls': "1.5 oz karlsson's gold vodka, .5 oz luxardo amaretto di saschira, .5 oz benedictine, .5 oz orange juice, .5 oz honey",
#  'virgil st.': "1 oz mezcal, .75 oz tempus fugit alessio vermouth di torino rosso, .5 oz old tom gin, .5 oz tempus fugit kina l'aero d'or, 1 dash duplais swiss absinthe verte",
#  'wabash avenue sour': '2 oz bourbon, 1 oz fresh lemon juice, .5 oz luxardo sangue morlacco cherry liqueur, .5 oz small hand foods pineapple gum syrup, .5 oz egg white',
#  'war of the roses': '.75 c junipero gin, .75 c c. drouin calvados selection, .5 c lemon juice, .5 c ginger-vanilla syrup, 4 dash angostura bitters, 1 bottle sparkling rose',
#  'west coast punch': '1.5 oz junipero gin, .75 oz pineapple juice, .5 oz monin strawberry puree, 6-7  mint leaves, .5 oz lemon sour, 1 oz lemon lime soda',
#  'west coast vesper': '1 oz hophead vodka, 1 oz junipero gin, .5 oz maurin quina',
#  "where's the orgeat?": '2 oz h by hine, 1 oz small hand foods orgeat, .75 oz lemon juice, .5 oz luxardo apricot liqueur, 3 dash angostura bitters',
#  'white lady': '2 oz junipero gin, .5 oz luxardo triplum (triple sec), .5 oz lemon juice, 1  egg white',
#  'white lady (classic) (adapted)': '1.5 oz no.3 london dry gin, .75 oz luxardo triplum (triple sec), .75 oz fresh lemon juice, .5 oz egg white',
#  'white tie': '1 oz luxardo bitter bianco, 2 oz no.3 london dry gin, 2 dash orange bitters, 1 bsp luxardo maraschino liqueur',
#  'white walker flip': "1 oz glenrothes vintage reserve, 1 oz king's ginger liqueur, .25 oz green chartreuse, .75 oz sweetened apple cider, 2 dash baked apple bitters, 1 whole egg",
#  'willow': '1 oz old potrero straight rye whiskey, 1.5 oz barsol perfecto amor (aperitif wine), 1 bsp luxardo amaro abano, 1 dash angostura bitters',
#  'windtalker': "1.5 oz hirsch small batch reserve bourbon, .75 oz luxardo amaretto di saschira, .5 oz king's ginger liqueur, .75 oz fresh lemon juice, .5 oz egg white",
#  'winter season': '2 oz barr hill honey gin, 1 oz lemon juice, .25 oz liquid alchemist orgeat, .25 oz luxardo maraschino liqueur, 1 bsp dijon blue curaçao',
#  'winter swizzle': '2 oz pink pigeon rum, 1 oz fresh lime juice',
#  'yawkey way ': '1.5 oz no.3 london dry gin, .5 oz smith & cross, .5 oz strawberry juice, .5 oz black tea syrup, .5 oz lemon juice, 2 dashes orange bitters',
#  'yellow bird': 'white rum,galliano,triple sec,lime juice',
#  'yes, queen!': '2 oz h by hine, 1 oz dolin dry vermouth, .5 tsp giffard banane du brésil, .5 tsp honey syrup',
#  'you bet your ascot': '1.5 oz h by hine, .75 oz bonal, .5 oz luxardo amaro abano, .25 oz nocino',
#  "you're bitter than that": '.75 oz blanco tequila, .75 oz luxardo bitter bianco, .75 oz luxardo sangue morlacco cherry liqueur, .75 oz fresh lime juice, .25 oz rich simple syrup (2:1)',
#  'ypioca chile punch': '2 part ypioca brasilizar cachaca prata classica, 1 part fresh lime juice, .5 part agave, .5 part ancho reyes ancho chile liqueur',
#  'ypioca yellow card': "1.5 oz ypioca brasilizar cachaca prata reserva especial, .5 oz king's ginger liqueur, 1 oz pineapple juice, .5 oz simple syrup, 2 oz coconut water, 1 fill soda water",
#  "zippy's revenge": 'amaretto,rum,kool-aid',
#  'zorbatini': 'vodka,ouzo',
#  '“prepare for destiny! where’s my pizza?”': '1 oz green hat spring/summer gin, .25 oz luxardo maraschino liqueur, .5 oz lime, .5 oz sugar rich simple, 1 dash celery bitters, 3 oz fever-tree soda'}

# %% [markdown]
# # fjdihg

# %%
import csv


def read_file(file):
    with open(file) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        cocktail_names = []
        tags = []
        out = {}
        for row in csv_reader:
            if line_count == 0:
                print(f'Column names are {", ".join(row)}')
                line_count += 1
                # out.append(row)
            else:
                # for idx, item in enumerate(row):
                #     if idx == 0:
                #         out.append([item])
                #     else:
                #         out[-1] += item.split(',')
                # print(out[-1])
                # cocktail_names += row[1]
                # tags += row[2].split(',')
                out[row[1]] = row[2]
                print(row[2])
    return out



data = read_file("cocktail_tags.csv")
# tags = [data[cocktail] for cocktail in data.keys()]
# [item for sublist in tags for item in sublist]
print(len(data))

# %%
import csv
import pandas as pd

input = pd.read_csv('cocktail_flavors.csv')
input['combined'] = input['Ingredients']
input['flavors'] = ''

flavors = ['floral', 'citrus', 'herbaceous', 'fruity', 'spicy', 'sweet', 'bitter']
for index, row in input.iterrows():
    for flavor in flavors:
      if row[flavor]:
          input.at[index, 'combined'] = input.at[index, 'combined'] + f",{flavor}"
          input.at[index, 'flavors'] = input.at[index, 'flavors'] + f",{flavor}"

input.to_csv("cocktail_flavors_ingreds_combined.csv", index=False)

# %%
import csv

file = 'popularity.csv'
drink_popularity = {}
with open(file) as csv_file:
    csv_reader = csv.reader(csv_file)

    for row in csv_reader:
        # if line_count == 0:
        #     print(f'Column names are {", ".join(row)}')
        #     line_count += 1
        # out.append(row)
        # for idx, item in enumerate(row):
        #     if idx == 0:
        #         out.append([item])
        #     else:
        #         out[-1] += item.split(',')
        # print(out[-1])
        # cocktail_names += row[1]
        # tags += row[2].split(',')
        # print(row[2])
        if not row[2] in drink_popularity:
            drink_popularity[row[2].lower()] = ''

    print(len(drink_popularity))


def read_file_ingreds(file):
    """ Returns a dictionary of format {'cocktail name' : 'ingred1,ingred2'}
    Parameters:
    file: name of file

    ***Note: CURRENTLY CONFIGURED FOR cocktail_flavors_ingreds_combined***
    """
    with open(file, encoding="utf8") as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        out = {}
        for row in csv_reader:
            if line_count == 0:
                line_count += 1
            else:
                out[row[0].lower()] = row[3].lower()
    return out


drink_ingreds = read_file_ingreds('cocktail_flavors_ingreds_combined.csv')

count = 0
common_drinks = {}
for drink in drink_popularity:
    if drink in drink_ingreds:
        count += 1
        common_drinks[drink] = ''
    else:
        for drink2 in drink_ingreds:
            if drink in drink2 or drink2 in drink:
                count += 1
                common_drinks[drink2] = ''


# set(drink_popularity.keys()).intersection(drink_ingreds.keys())
print(common_drinks.keys())
# Out:
# 101
# dict_keys(["'57 chevy with a white license plate", 'caipirinha', 'brazilian mai tai', 'kentucky mai tai', 'lemon drop', 'mojito', 'ace', 'tequila sunrise', 'martini', 'flambeed brandy alexander', 'kir', 'manhattan'])

# %%
def read_file_popularity(file):
        """ Returns a dictionary of format {'cocktail name' : 'flavor1,flavor2'}
        Parameters:
        file: name of file

        """
        with open(file, encoding="utf8") as csv_file:
            csv_reader = csv.reader(csv_file, delimiter=',')
            line_count = 0
            out = {}
            for row in csv_reader:
                if line_count == 0:
                    line_count += 1
                else:
                    out[row[0].lower()] = row[12]
        return out

read_file_popularity('cocktail_flavors_popularity.csv')
