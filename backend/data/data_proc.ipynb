# %%
import csv


def read_file(file):
    with open(file) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        cocktail_names = []
        tags = []
        out = {}
        for row in csv_reader:
            if line_count == 0:
                print(f'Column names are {", ".join(row)}')
                line_count += 1
                # out.append(row)
            else:
                # for idx, item in enumerate(row):
                #     if idx == 0:
                #         out.append([item])
                #     else:
                #         out[-1] += item.split(',')
                # print(out[-1])
                # cocktail_names += row[1]
                # tags += row[2].split(',')
                out[row[1]] = row[2]
                print(row[2])
    return out



data = read_file("cocktail_tags.csv")
# tags = [data[cocktail] for cocktail in data.keys()]
# [item for sublist in tags for item in sublist]
print(len(data))
# Out:
# Column names are , drink, tags, IBA
# Alcoholic,Holiday
# IBA,Classic
# IBA,Classic,Dairy
# IBA,NewEra
# ContemporaryClassic,IBA
# IBA,NewEra
# Alcoholic,Sweet,DateNight,USA
# IBA,NewEra
# IBA
# ContemporaryClassic,IBA
# IBA,ContemporaryClassic
# IBA,Classic
# IBA,ContemporaryClassic
# Classic,IBA
# IBA,Classic,Beach
# IBA,Classic,Christmas,Alcoholic
# IBA,NewEra
# IBA,NewEra
# Drunk
# IBA,NewEra
# DinnerParty,StrongFlavor
# Brazilian
# Cold, Frozen, Summer
# IBA,ContemporaryClassic
# Christmas,Sweet
# NewEra,IBA
# IBA,ContemporaryClassic
# IBA,Classic
# Sour
# IBA,ContemporaryClassic
# IBA,ContemporaryClassic
# Citrus,StrongFlavor
# IBA,ContemporaryClassic,Halloween
# Clear,Alcoholic
# Sweet
# Winter
# IBA,ContemporaryClassic
# Halloween
# IBA,ContemporaryClassic
# IBA,ContemporaryClassic
# IBA,ContemporaryClassic
# IBA
# Beach
# IBA,ContemporaryClassic
# IBA,NewEra
# Green, Sharp
# IBA,NewEra
# Strong,Asia,StrongFlavor,Brunch,Vegetarian,Sour
# Lazy, Sharp
# IBA,ContemporaryClassic
# Summer, Fresh, Refreshing
# IBA,ContemporaryClassic,Alcoholic,USA,Asia,Vegan,Citrus,Brunch,Hangover,Mild
# IBA,ContemporaryClassic
# IBA,ContemporaryClassic
#
# Hangover,StrongFlavor,Breakfast
# IBA,Classic,Alcoholic
# IBA,ContemporaryClassic
# IBA,ContemporaryClassic
# IBA
# IBA,ContemporaryClassic
# Christmas
# German
# Fruity
# IBA,Classic
# IBA,Classic
# IBA,Classic
# IBA,Classic,Alcoholic,Expensive,Savory
# Citrus
# IBA
# Fresh, Summer, Colourful, Nature
# IBA,NewEra
# IBA,Classic
# IBA,ContemporaryClassic
# Passion
# IBA,Classic
# Adult, Shot, Bubbly
# IBA,ContemporaryClassic
# IBA,Classic
# IBA,NewEra
#
# IBA,Classic
# IBA,Classic
# IBA,Classic
# Winter
# Christmas
# Christmas
# IBA,ContemporaryClassic
# IBA
# Dark
# Drunk
# IBA,ContemporaryClassic
# IBA,Classic
# IBA,NewEra
# IBA,NewEra
# IBA,Classic
# Winter
# IBA,Classic,Alcoholic,ContemporaryClassic
# Winter
# Spanish
# IBA,NewEra
# 101

# %%
import csv
import pandas as pd

input = pd.read_csv('cocktail_flavors.csv')
input['combined'] = input['Ingredients']
input['flavors'] = ''

flavors = ['floral', 'citrus', 'herbaceous', 'fruity', 'spicy', 'sweet', 'bitter']
for index, row in input.iterrows():
    for flavor in flavors:
      if row[flavor]:
          input.at[index, 'combined'] = input.at[index, 'combined'] + f" {flavor}"
          input.at[index, 'flavors'] = input.at[index, 'flavors'] + f"{flavor} "

input.to_csv("cocktail_flavors_ingreds_combined.csv", index=False)
